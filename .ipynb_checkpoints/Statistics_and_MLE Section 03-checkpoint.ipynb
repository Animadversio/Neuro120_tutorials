# %%
# !jt -t chesterish

# %%
import matplotlib.pylab as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Neuro120 Section 3 Probability and MLE Review

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Probability" data-toc-modified-id="Probability-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Probability</a></span><ul class="toc-item"><li><span><a href="#A-Meta-Note-on-Probability" data-toc-modified-id="A-Meta-Note-on-Probability-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>A Meta Note on Probability</a></span></li><li><span><a href="#Joint-Probability" data-toc-modified-id="Joint-Probability-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Joint Probability</a></span></li><li><span><a href="#Marginal-Distribution" data-toc-modified-id="Marginal-Distribution-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Marginal Distribution</a></span></li><li><span><a href="#Conditional-Probability" data-toc-modified-id="Conditional-Probability-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Conditional Probability</a></span></li><li><span><a href="#Bayes-Rule" data-toc-modified-id="Bayes-Rule-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Bayes Rule</a></span></li><li><span><a href="#Extra:-Bayesian-and-Frequentist" data-toc-modified-id="Extra:-Bayesian-and-Frequentist-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Extra: Bayesian and Frequentist</a></span></li></ul></li><li><span><a href="#Statistical-Inference" data-toc-modified-id="Statistical-Inference-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Statistical Inference</a></span><ul class="toc-item"><li><span><a href="#(my)-Philosphy-of-Statistical-Inference" data-toc-modified-id="(my)-Philosphy-of-Statistical-Inference-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>(my) Philosphy of Statistical Inference</a></span></li><li><span><a href="#Likelihood" data-toc-modified-id="Likelihood-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Likelihood</a></span></li><li><span><a href="#Maximal-Likelihood-Estimate" data-toc-modified-id="Maximal-Likelihood-Estimate-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Maximal Likelihood Estimate</a></span></li><li><span><a href="#Analytical-Example:-MLE-of-a-Normal-Distribution" data-toc-modified-id="Analytical-Example:-MLE-of-a-Normal-Distribution-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Analytical Example: MLE of a Normal Distribution</a></span></li><li><span><a href="#MLE-and-optimization" data-toc-modified-id="MLE-and-optimization-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>MLE and optimization</a></span></li><li><span><a href="#Fisher-Information" data-toc-modified-id="Fisher-Information-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Fisher Information</a></span><ul class="toc-item"><li><span><a href="#Geometric-of-Hessian:-Eigenvalue-and-Curvature" data-toc-modified-id="Geometric-of-Hessian:-Eigenvalue-and-Curvature-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>Geometric of Hessian: Eigenvalue and Curvature</a></span></li></ul></li><li><span><a href="#Observed-Fisher-Information" data-toc-modified-id="Observed-Fisher-Information-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Observed Fisher Information</a></span><ul class="toc-item"><li><span><a href="#Fisher-Information-and-Theoretical-Result" data-toc-modified-id="Fisher-Information-and-Theoretical-Result-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Fisher Information and Theoretical Result</a></span></li></ul></li><li><span><a href="#Extra:-Information-Geometry-and-Sloppiness" data-toc-modified-id="Extra:-Information-Geometry-and-Sloppiness-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Extra: <strong>Information Geometry</strong> and Sloppiness</a></span></li><li><span><a href="#Extra:-MLE-and-MAP-(Maximum-a-posteriori-estimation)" data-toc-modified-id="Extra:-MLE-and-MAP-(Maximum-a-posteriori-estimation)-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Extra: MLE and MAP (Maximum a posteriori estimation)</a></span></li><li><span><a href="#Extra:-MAP-and-Regularization" data-toc-modified-id="Extra:-MAP-and-Regularization-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Extra: MAP and Regularization</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Probability
#
# The flow is inspired by Probability lecture in [CS188, Berkeley](https://inst.eecs.berkeley.edu/~cs188/su21/). [slides](https://drive.google.com/file/d/1v4D8grhn1M4uijGJGhKN8rFDpbdcK4E_/view)

# %% [markdown]
# Simply put, probability represents how likely something happens.
#
# * Each event is assigned a non-negative value -> how likely it happens. $$p(E)\geq 0$$
#
# In practise, we consider probabilities for **discrete or continuous or variable**, each evaluation of the variables have a probability (density)
# $$p(X=x)\;,x\in\mathcal X$$
# * It's a mapping from the space of outcomes to some real number.

# %% [markdown]
# <img src=attachment:image.png>

# %% [markdown]
# Here I'll revive your intuition for **joint, marginal, conditional distribution, Bayes rule** for the discrete variable case. The same basic intuition holds for continuous distributions with some subtlety.

# %% [markdown]
# ### A Meta Note on Probability

# %% [markdown]
# One key property for probability is its summing to one.
# $$\sum_{x\in\mathcal X}P(X=x)=1$$
#
# Many parts, constants in probability formula come just from this criterion.
# * In many cases we can drop those "Normalization factors" when thinking, and add them back when necessary. Keep the formula as $\propto$ instead of $=$
#     * Many cases, we term the normalization factor as $Z$
# * We can calculate them post-hoc by summing things to one.
# * One has to note what variable Normalization factors depends on, if it depends on some parameter of interest, we may not drop it so easily.

# %% [markdown]
# Another note is, notation is super important. When deriving, make clear when a symbol is a number or it's a random variable / distribution.
# * $X,Y$ random variables
# * $x,y$ concrete values, numbers, outcomes.

# %% [markdown]
# ### Joint Probability

# %% [markdown]
# > Where is the ensemble all the information?
#
# For joint distribution, imagine a **Giant table** categorizing all possible combinations of events and their probability; or imagining a **density function** over a multi denmensional space.
# $$p(X,Y)$$
# ![image.png](attachment:image.png)

# %% [markdown]
# * In many cases, joint distribution contains **all** the desired information. All other info can be derived from this giant table.
#     * "joint probability of image and label"
#     * "joint probability of stimuli and neural response"
#     * "joint probability of neural state and behavior"
# * It's great if we can model the joint distribution! (check out probability graph models!) But due to intractability, ML problems usually tackle part of it like the conditional or mariginal distribution.

# %% [markdown]
# ### Marginal Distribution

# %% [markdown]
# To marginalize, you just need sum up all variables or along dimensions in the event space you don't care.
# * Just colapse the joint. No renormalization is needed.
#
# $$p(X=x) = \sum_{(x,y)\mid x=X} p(X=x,Y=y)$$

# %%
df = sns.load_dataset('iris')
df# Custom the inside plot: options are: “scatter” | “reg” | “resid” | “kde” | “hex”
sns.jointplot(data=df, x="sepal_length", y="sepal_width", hue="species", kind='hist', bins=15)
sns.jointplot(data=df, x="sepal_length", y="sepal_width", hue="species", kind='scatter')
sns.jointplot(data=df, x="sepal_length", y="sepal_width", hue="species", kind='kde')
# sns.jointplot(x=df["sepal_length"], y=df["sepal_width"], kind='kde')

# %% [markdown]
# ### Conditional Probability

# %% [markdown]
# Conditional probability is the probability of events given some conditions. How do we compute it?
# * The conditions **eliminate** part of the outcome space. $\{(x,y)\mid x=X\}$ retain outcomes that are consistent with condition.
# * The relative probability do not change. So just renormalize using the **sum of the rest outcomes**.
#
# $$p(y\mid x=X)\propto p(x=X,y)$$
# $$Z=\sum_{(x,y)\mid x=X} p(x,y) = p(x=X)$$

# %% [markdown]
# Thus plugging in the normalization factor, we get this classic formula
# $$p(y\mid x)=p(x,y)/p(x)$$

# %% [markdown]
# <img src=attachment:image.png width=600>

# %% [markdown]
# Another way to write this is also known as **product rule**:
# $$p(x,y)=p(y\mid x)p(x)$$
# You can use product rule **in a chain** to algebraically decompose the joint whatever you like
#     $$p(x,y,z)=p(x,y\mid z)p(z)=p(x\mid y,z)p(y,z)=p(x\mid y,z)p(y\mid z)p(z)$$

# %% [markdown]
# ### Bayes Rule

# %% [markdown]
# > How to infer the inverse direction conditional probability ?
#
# Derivation of Bayes rule is not hard: Two ways of decomposing a joint distribution are equal to each other using the product rule.
# $$p(x=X,y=Y) = p(y=Y\mid x=X)p(x=X) = p(x=X\mid y=Y)p(y=Y)$$
# $$\frac{p(y=Y\mid x=X)p(x=X)}{p(y=Y)} = p(x=X\mid y=Y)$$
# $$\frac{p(y=Y\mid x)p(x)}{p(y=Y)} = p(x\mid y=Y)$$
# Why it is interesting? Why it's not a boring algebraic trick?

# %% [markdown]
# The significance comes from our usage of it,
# * Joint is inaccessible most of the time.
# * But when conditional probability of one direction is more accessible than the other, we may infer the conditional probability $X\mid Y$ from its reverse $Y\mid X$.
# * Think of $Y$ as effect (symptom) and $X$ as cause (disease), then we may know $p(effect\mid cause)$ from data but not the reverse. We inference the cause using Bayes rule.

# %% [markdown]
# Usually, we interpret Bayes rule as (in Bayesian framework),
# * $Y$ is the observed evidence. $X$ is the hidden cause.
# * $p(x)$ is a prior distribution on the cause. Our belief.
# * Then during inference, we weight the prior distribution with the *association strength of different causes and evidence*. Then renormalize.
# $$p(x\mid y=Y)\propto p(x)p(y=Y\mid x)$$
# $$Z = \sum_{x=X} p(x=X)p(y=Y\mid x=X)$$

# %% [markdown]
# [3b1b video on Bayes rule](https://www.youtube.com/watch?v=HZGCoVF3YvM)
# <img width=700 src=attachment:image.png>

# %% [markdown]
# ### Extra: Bayesian and Frequentist
# > Is probability objective or subjective?

# %% [markdown]
# This rule is linked to the philosophical divide of probability, what is that?

# %% [markdown]
# * Frequentist: probability reflect the outcome distribution of repeated experiments.
#     * probability $p(x=X)$ is the frequency of outcome $x=X$ if we conduct infinite repeated experiments on $x$
#     * Sounds simple and fair (coins!) but non-realizable in many cases.
#     * *Objective but theoretical* (Platonic)
# * Bayesian: probability reflect our belief or without on the world.
#     * It's a belief about the state of the world, given all the evidence we observed.
#     * It's initialized with a prior.
#     * It can be updated based on new observations.
#     * *Subjective but empirical* (Aristotelian)

# %% [markdown]
# What's the issue with Frequentist view here?
# <img src=https://www.explainxkcd.com/wiki/images/7/78/frequentists_vs_bayesians.png width=450>

# %% [markdown]
# * *Argument against Freq*: Is there any repeated experiments?
#     * Proportion of disease in the population?
# * *Argument against Bayes*: What is your prior really?

# %% [markdown]
# ## Statistical Inference

# %% [markdown]
# ### (my) Philosphy of Statistical Inference

# %% [markdown]
# When doing science we usually do some manipulations, observe and record some data (e.g. spikes). Data itself is great, but we want to draw conclusions about something else, something **greater**:
# * the underlying mechanisms or processes that generate this data.
# * whether our understanding of the system (hypothesis) is correct.
#
# When doing so, we need **inference**.

# %% [markdown]
# Generally, for a process of interest (say visual processing), we assume mother nature has a true **data generating process**, formalized as $G$. This process takes an experiment variable $x$ as input and maps it to a distribution of data $G(x)=p(y|x)$. Our data are sampled from such distribution
# $$y\sim G(x)$$
#
# To note, actual experiments as data generating process are noisy versions of this true one.

# %% [markdown]
# However, for many processes (esp. biology), we don't know this true function $G$, we don't even know the form of it!

# %% [markdown]
# The best we can do is to **approximate** this function with some function forms we know,
# $$\mathcal F=\{\theta\in\Theta|f(.;\theta)\}$$
# , parametrized with $\theta$. We will try to get some knowledge of the parameter $\theta$ and draw conclusions about the system.

# %% [markdown]
# Note many statistical methods could be regarded in this perspective.
# * t-test: we approximate / assume the data generating process by a normal distribution $\mathcal N(\mu,\sigma)$; we want to test something about $\mu$.
# * Parameters estimation for a fancy model of data generation $G(\theta)$
# * Bootstrapping / shuffling: we don't presume a form of distribution, but just resample the existing data to simulate the data generating process.

# %% [markdown]
# Usually what we desire is the probability of certain hypothesis being true or certain parameter being correct, given my data!
# $$p(Hypothesis=True\mid data)$$
# $$p(\theta=\theta^*\mid data)$$
#
# But this is usually in accessible to us mortals. Usually what we can do is to test **how likely my data generating process produce the data.**
# $$p(data\mid Hypothesis=True)$$
# $$p(data\mid \theta=\theta^*)$$
# * simple ones like t-test, ANOVA, assess the probability for null hypothesis to generate the data.
# * **maximum likelihood inference** (MLE), give a point estimate of the parameter $\theta$ by finding $\theta$ that maximize likelihood function.
# * Bootstrapping and Shuffling, test if  *random* data generating process can reproduce similar result, then my result is not significant.

# %% [markdown]
# ### Likelihood

# %% [markdown]
# We talk about likelihood in the context of statistical inference. It's the **probability of sample data, given parameter of the model**.
# $$\mathcal L(\theta)=p(\{X_i\}\mid \theta)$$
# * The sample data is deemed fixed number.
# * It's just a function of parameters.

# %% [markdown]
# ### Maximal Likelihood Estimate

# %% [markdown]
# Maximum likelihood estimate is basically searching for parameters that have the largest likelihood to produce observed data
# $$\hat\theta_{MLE} = \arg\max_\theta p(\{X_i\}\mid \theta)=\arg\max_\theta\mathcal L(\theta)$$

# %% [markdown]
# In practise, we usually minimize negative log likelihood function (NLL), which have the same solution
# $$\hat\theta_{MLE} = \arg\min_\theta-\log\mathcal L(\theta)$$

# %% [markdown]
# Note, MLE is not the only way of estimating parameters, but due to its [attractive theoretical properties](https://engineering.purdue.edu/ChanGroup/ECE645Notes/StudentLecture08.pdf), it and its variants are used most of the time.
# * **Consistency**: Given enough sample, the estimate $\theta_{MLE}$ will converge to true sample.
# * **Normality**: Given enough sample, the estimate $\theta_{MLE}$ distributes normally.
# * efficiency etc.

# %% [markdown]
# ### Analytical Example: MLE of a Normal Distribution

# %% [markdown]
# Take a simple example, we have some data $\{X_1,...X_n\}$. We **hypothesize** the data generative process is i.i.d. sampling from Gaussian distribution, that is to say our family is
# $$\mathcal F=\{\mu\in\mathbb R,\sigma>0\mid \mathcal N(\mu,\sigma)\}$$
#
# We can use MLE to estimate the best parameter $(\mu,\sigma)$ in this family that generates the data.

# %% [markdown]
# Recall the density of normal distribution is
# $$p(x)=\frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{(x-\mu)^{2}}{2\sigma^{2}}}$$
#
# So, the probability of getting our data given $(\mu,\sigma)$ is
#
# $$p(\{X_1,X_2,...X_n\}\mid \mu,\theta)=\prod_i p(X_i\mid \mu,\theta)\\
# =\prod_i\frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{(X_i-\mu)^{2}}{2\sigma^{2}}}\\
# =(\sigma\sqrt{2\pi})^{-n}e^{-\sum_i\frac{(X_i-\mu)^{2}}{2\sigma^{2}}}$$

# %% [markdown]
# This probaility is our likelihood.
# $$\mathcal L(\mu,\theta)=(\sigma\sqrt{2\pi})^{-n}e^{-\frac{\sum_i(X_i-\mu)^{2}}{2\sigma^{2}}}$$

# %% [markdown]
# For MLE, it doesn't hurt to transform the likelihood function with a **monotonic function** like log.
#
# $$\begin{align}\log\mathcal L(\mu,\theta)=& -n\log(\sigma\sqrt{2\pi}) - \frac{\sum_i(X_i-\mu)^{2}}{2\sigma^{2}}\\
# =& -\frac n2\log(2\pi) -n\log(\sigma) - \frac{\sum_i(X_i-\mu)^{2}}{2\sigma^{2}}
# \end{align}$$

# %% [markdown]
# MLE solves this maximization problem
# $$\hat \theta = \arg\max_\theta \log\mathcal L(\theta) = \arg\max_\theta \mathcal L(\theta)$$
#
# To find the maximum of log likelihood, we need its gradient to be zero.
# $$\nabla \log\mathcal L(\mu,\theta)=\mathbb 0$$
# which translates to two equations,
# $$0=\partial_\mu \log\mathcal L = \frac{1}{\sigma^{2}}\sum_i(X_i-\mu)$$
# $$0=\partial_\sigma \log\mathcal L=-\frac n{\sigma}+\frac{\sum_i(X_i-\mu)^{2}}{\sigma^{3}}$$

# %% [markdown]
# Solving these two equations are surprisingly easy!
#
# We can solve $\mu$ independent of $\sigma$; and then bring $\hat \mu$ in.
# $$\hat \mu = \frac{1}{n}\sum_i X_i$$
# $$\hat\sigma =\sqrt\frac{\sum_i(X_i-\hat\mu)^{2}}{n}$$

# %% [markdown]
# We recover the formula for mean and standard deviation, which shed a new interpretation on these:
# * Sample mean and std are the best Gaussian parameters to generate a set of data.
# * This `std` estimate is biased for *finite* sample size. But correct in the limit.

# %% [markdown]
# ### MLE and optimization

# %% [markdown]
# For few cases like above, we can solve MLE by hand -- solving $\nabla_\theta \log\mathcal L(\theta)=0$ analytically.
#
# More often than not, we need to solve MLE numerically, which is solving an optimization problem, usually by gradient descent or Newton's method.

# %% [markdown]
# Loss landscape of likelihood (from Cristina Savin Neuromatch)
# <img src=attachment:image.png width=500>
#
# Here is an example of NLL loss landscape for the likelihood function for normal distribution.

# %%
Xs = [1,3,4,5,6,8,13]
n = len(Xs)
nll = lambda sigma,mu: -n * log(sigma)-sum((x-mu)**2 for x in Xs)/2/sigma**2
sig_space = np.linspace(1.5,11.5,100)
mu_space = np.linspace(0,10,100)
sigma, mu = np.meshgrid(sig_space,mu_space)
nllsurf = n * np.log(sigma) + sum((x-mu)**2 for x in Xs)/2/sigma**2

# %%
plt.contour(sig_space,mu_space,nllsurf,60)
plt.plot(np.std(Xs), np.mean(Xs), 'bo', label="MLE estimate")
plt.xlabel("sigma")
plt.ylabel("mu")
plt.axis("image")
plt.title("NLL landscape for normal distribution")
plt.colorbar(label="'negative log likelihood'")
plt.legend()

# %% [markdown]
# In the homework, you will use these methods to perform MLE for LNP models, you can refer to [this note](https://arxiv.org/pdf/1404.1999.pdf) for analytical help!

# %% [markdown]
# <img src=attachment:image.png width=600>

# %% [markdown]
# ### Fisher Information

# %% [markdown]
# > MLE is powerful, but it's a point estimate. What about the variance or range?
#
# MLE give us the **mode / peak** of the likelihood function, when we need to provide a range for the parameters, we need 2nd order information.

# %% [markdown]
# Recall from Taylor expansion, any functions look quadratic locally, when the gradient vanish, the function is dominated by the quadratic form of Hessian (2nd order derivative).
# $$f(x)=f(\hat x)+\nabla f(\hat x)\Delta x+\frac 12\Delta x^T\nabla^2 f(\hat x)\Delta x + ...\approx f(\hat x)+\frac 12\Delta x^T\nabla^2 f(\hat x)\Delta x$$

# %% [markdown]
# #### Geometric of Hessian: Eigenvalue and Curvature

# %% [markdown]
# **Question:** Given this quadratic function $f(x)=x^TQx$, and it's two eigen dimensions, which one has larger eigen value?
# $$Q=UDU^T\;\;\\D=diag(1,6)\;\;UU^T=I$$

# %%
# Little demo of Hessian of quadratic function
from scipy.stats import ortho_group
basis = ortho_group.rvs(2)
Q = basis @ np.diag([1,6]) @ basis.T
X, Y = np.linspace(-5,5,101),np.linspace(-5,5,101)
XX, YY = np.meshgrid(X, Y)
coord = np.stack([XX, YY])
# print(coord.shape)
fval = np.einsum("ij,ikl,jkl->kl",Q,coord,coord)
plt.figure(figsize=[7,7])
plt.contour(X,Y,fval,25)
plt.plot([0,basis[0,0]],[0,basis[1,0]],c='r',label="eig1")
plt.plot([0,basis[0,1]],[0,basis[1,1]],c='b',label="eig2")
plt.colorbar(label="'negative log likelihood'")
plt.legend()
plt.axis("image");

# %% [markdown]
# Having this intuition, it's clear why the Hessian of negative log likelihood is important to our cause:
# * On the eigen directions with smaller eigenvalue, landscape is flat, $\theta$ may vary a lot without changing $\mathcal L$ much.
# * On the directions of large eigenvalue, landscape is steep, the $\theta$ parameters are better constrained.

# %% [markdown]
# ### Observed Fisher Information

# %% [markdown]
# The observed information is the **Hessian matrix of the negtive log likelihood (NLL) function**, usually evaluated at the MLE solution $\hat\theta_{MLE}$, or the minimum of NLL function.
#
# Its elements could be written as
# $$I_{ij}(\hat\theta) =\partial_{\theta_i} \partial_{\theta_j} -\log \mathcal L(\theta)|_{\theta=\hat\theta}$$
# * It's symmetric.
# * It should be positive definite (only positive eigenvalues), if the MLE solution is unique.
# * Many optimization procedure like Newton's method will calculate this matrix just for free!

# %% [markdown]
# #### Fisher Information and Theoretical Result

# %% [markdown]
# The (theoretical) Fisher information matrix is the expectation of this Hessian matrix at the **true parameters**.
# $$\mathcal I(\theta^*)=\mathbb E_{\theta=\theta^*} [\partial_{\theta_i}\partial_{\theta_j}-\log\mathcal L(\theta)]$$
#
# Theoretical derivation shows that at large sample size $n$, the estimated parameter $\hat\theta$ distributed as
# $$\sqrt n(\hat\theta_{MLE}-\theta^*)\sim \mathcal N(0,\mathcal I^{-1}))$$
# That is to say, the error of MLE distribute approximately as normal distribution, with covariance matrix $\mathcal I^{-1}$.
# * The directions of large eigenvalues of $\mathcal I$ are estimated to higher precision!
# * The directions of small eigenvalues are sloppy, less constrained!

# %% [markdown]
# In this true parameter is unknown, usually we use the Observed Information to estimate it. In many cases, you will get a covariance matrix together with the optimal parameters, that's it.

# %% [markdown]
# ### Extra: **Information Geometry** and Sloppiness

# %% [markdown]
# > What is the geometry in the space of distributions?
#
# The family of distribution functions $\mathcal F= \{\theta\in\Theta\mid f(.;\theta)\}$ form a "manifold", and we can measure the distance on it with the Fisher information matrix (derivation [see](https://en.wikipedia.org/wiki/Fisher_information_metric)).
# $$g_{jk}(\theta)=\mathbb E_x[\partial_{\theta_j}\log p(x;\theta)\partial_{\theta_k}\log p(x;\theta)]$$
# $$g_{jk}(\theta)=\mathbb E_x[-\partial_{\theta_j}\partial_{\theta_k}\log p(x;\theta)]=\mathcal I(\theta)$$

# %% [markdown]
# Why this is interesting at all?
# * A website dedicated to [sloppiness in scientific models](https://www.lassp.cornell.edu/sethna/Sloppy/)
# * [Parameter Space Compression Underlies Emergent Theories and Predictive Models, Science](https://www.science.org/doi/abs/10.1126/science.1238723)
# * [Perspective: Sloppiness and emergent theories in physics, biology, and beyond](https://aip.scitation.org/doi/10.1063/1.4923066)

# %% [markdown]
# Complex models as we will use have many parameters, their eigen spectrum naturally distributed on log scale.
# <img width=600 src=https://aip.scitation.org/na101/home/literatum/publisher/aip/journals/content/jcp/2015/jcp.2015.143.issue-1/1.4923066/production/images/medium/1.4923066.figures.f1.gif >

# %% [markdown]
# It's possible to prune out certain parameter of the model while retaining model performance, by compressing certain model parameter combinations.
# <img width=700 src=https://aip.scitation.org/na101/home/literatum/publisher/aip/journals/content/jcp/2015/jcp.2015.143.issue-1/1.4923066/production/images/medium/1.4923066.figures.f5.gif>

# %% [markdown]
# ### Extra: MLE and MAP (Maximum a posteriori estimation)

# %% [markdown]
# > What if you have some prior knowledge of the parameter?
#
# Sometimes you will encounter MAP inference in paper, which is closely related to MLE.
#
# In Bayesian inference framework this is a way to incorporate your prior knowledge.

# %% [markdown]
# Say, from domain knowledge or design we have some prior knowledge about the parameter $\theta$, like a distribution $g(\theta)$
# Then our *a posteriori* distribution is
# $$p(\theta\mid\{X_i\})=\frac{p(\{X_i\}\mid \theta)g(\theta)}{\int_\vartheta p(\{X_i\}\mid \vartheta)g(\vartheta) d\vartheta}\propto p(\{X_i\}\mid \theta)g(\theta)$$
#
# So formula for MAP inference is,
# $$\hat\theta_{MAP} =\arg\max_\theta p(\theta\mid\{X_i\})= \arg\max_\theta p(\theta \mid \{X_i\})g(\theta)$$

# %% [markdown]
# So don't be afraid when you see MAP next time. But what's good about this?

# %% [markdown]
# ### Extra: MAP and Regularization

# %% [markdown]
# > Two interpretations of the same math: how to limit the complexity of our model?

# %% [markdown]
# Recall the overfitting problem introduced before. A model can be too complex and fit the data too well and generalize poorly.
#
# A common technique in regression and machine learning is to **add regularization term to the loss function**.
# * L1 regularization $\|\theta\|_1$
# * L2 regularization $\|\theta\|_2^2=\sum_i \theta_i^2$
#
# For MLE we can do the same trick, (using negative log likelihood)
# $$\hat \theta_{regMLE}=\arg\min_\theta -\log \mathcal L(\theta)+\beta \|\theta\|^2_2$$

# %% [markdown]
# But what does this mean?
#
# Actually, we can interpret it in the MAP framework.

# %% [markdown]
# For MAP estimation, we can write the formula in NLL term.
# $$\hat\theta_{MAP} = \arg\min_\theta -\log \mathcal L(\theta)-\log g(\theta)$$
#
# Note the 2nd term correspond to the $\beta\|\theta\|_2^2$ term above!

# %% [markdown]
# Thus, we know that the regularized MLE is identical to MAP estimate, when **the negative log density of prior is proportional to the regularization term.** (It's not equal because some normalization constant can be dropped.)

# %% [markdown]
# * For L2 regularization
#     $$g(\theta)\propto \exp(-\beta\|\theta\|_2^2)=\exp(-\beta\sum_i\theta_i^2)$$
#    * The prior for each parameter is i.id **Gaussian distribution** with 0 mean and variance $1/2\beta$.
# * For L1 regularization
#     $$g(\theta)\propto \exp(-\beta\|\theta\|_1)=\exp(-\beta\sum_i|\theta_i|)$$
#    * The prior for each parameter is i.id [**Laplace distribution**](https://en.wikipedia.org/wiki/Laplace_distribution) with 0 mean and variance $2/\beta^2$.

# %% [markdown]
# Here is a plot with the two distributions, with matching first 3 moments matching (mean variance skewness)
#
# From this plot, **tell me why L1 regularization is called "sparse prior"**

# %%
from scipy.stats import laplace, norm
lapl = laplace(0, 1/np.sqrt(2)) # set the b parameter
fig, ax = plt.subplots(1, 1)
mean_l, var_l, skew_l, kurt_l = lapl.stats(moments='mvsk')
mean_n, var_n, skew_n, kurt_n = norm.stats(moments='mvsk')
print("Laplace: mean %.1f var %.1f skew %.1f kurt %.1f"%(mean_l, var_l, skew_l, kurt_l))
print("Gaussian: mean %.1f var %.1f skew %.1f kurt %.1f"%(mean_n, var_n, skew_n, kurt_n))
x = np.linspace(lapl.ppf(0.01),lapl.ppf(0.99), 100)
ax.plot(x, lapl.pdf(x),
       'r-', lw=5, alpha=0.6, label='Laplace pdf')
ax.plot(x, norm.pdf(x),
       'b-', lw=5, alpha=0.6, label='Gaussian pdf')
ax.legend();
# Out:
# Laplace: mean 0.0 var 1.0 skew 0.0 kurt 3.0
# Gaussian: mean 0.0 var 1.0 skew 0.0 kurt 0.0

# %% [markdown]
# Here is another visualization of this intuition (from Cristina Savin pre in Neuromatch)
# <img src=attachment:image.png width=700>

# %% [markdown]
# What does this Bayesian interpretation teach us about regularization?
# * L2 and L1 regularization is applying same prior distribution on all parameters, if some of them tend to have dramatically different scale then it doesn't make sense.
#     * So normalize your features and parameters properly in linear model $f(k\cdot x)$.

# %% [markdown]
# # Homework Q&A
